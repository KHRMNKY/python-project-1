# %% [markdown]
# <a href="https://colab.research.google.com/github/kahramankaya/python-project-1/blob/main/s%C4%B1nav_sonuclar%C4%B1_anal%C4%B1z.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
veriler = """
225541003 60,00
215541009 57,89
225541059 60,00
215541097 57,89
225541011 65,79
225541035 50,00
225542005 42,11
225541089 60,53
225541017 52,00
225542017 31,58
225541057 34,21
225541003 68,00
215541025 39,47
225541015 34,21
225541021 52,63
225542015 44,74
225541081 44,74
225541027 63,16
225541025 57,89
225541039 39,47
225541065 50,00
225542013 60,53
225541009 63,16
225542001 39,47
225541007 31,58
225541063 57,89
225541055 60,00
225541029 50,00
225541995 50,00
225541013 26,32
225541045 42,11
225541031 50,00
225544077 50,00
225541095 55,26
215542001 52,63
225541043 36,84
225541037 52,63
225542011 36,84
225541049 55,26
225541061 39,47
220542011 81,00
210541109 31,58
225541115 50,00
220541609 15,79
210542019 34,21
220541087 57,89
210542007 65,79
210541045 68,42
220541063 50,00
220542001 47,37
225541103 36,84
210541027 47,37
220541103 36,84
220541077 36,84
220541035 60,53
220541031 39,47
220541033 55,26
220541033 55,26
220541047 57,89
220541065 28,95
220541013 44,74
220541023 55,26
220542017 63,16
220541081 44,74
220541005 79,00
220541067 60,00
190541051 52,63
220541071 34,21
"""

# %%
list=[]
data1=veriler.split("\n")
for i in data1[1:-1]:
  list.append(i)
list
# Out:
# ['225541003 60,00',
#  '215541009 57,89',
#  '225541059 60,00',
#  '215541097 57,89',
#  '225541011 65,79',
#  '225541035 50,00',
#  '225542005 42,11',
#  '225541089 60,53',
#  '225541017 52,00',
#  '225542017 31,58',
#  '225541057 34,21',
#  '225541003 68,00',
#  '215541025 39,47',
#  '225541015 34,21',
#  '225541021 52,63',
#  '225542015 44,74',
#  '225541081 44,74',
#  '225541027 63,16',
#  '225541025 57,89',
#  '225541039 39,47',
#  '225541065 50,00',
#  '225542013 60,53',
#  '225541009 63,16',
#  '225542001 39,47',
#  '225541007 31,58',
#  '225541063 57,89',
#  '225541055 60,00',
#  '225541029 50,00',
#  '225541995 50,00',
#  '225541013 26,32',
#  '225541045 42,11',
#  '225541031 50,00',
#  '225544077 50,00',
#  '225541095 55,26',
#  '215542001 52,63',
#  '225541043 36,84',
#  '225541037 52,63',
#  '225542011 36,84',
#  '225541049 55,26',
#  '225541061 39,47',
#  '220542011 81,00',
#  '210541109 31,58',
#  '225541115 50,00',
#  '220541609 15,79',
#  '210542019 34,21',
# ...

# %% [markdown]
# #vizede 80 puanı geçen kişi sayısı

# %%
list2=[]
i=0
for n in list:
  variable=n.replace(",",".")
  list2.append(variable)
for m in list2:
  if float(m[10:])>=80:
    i+=1
  else:
    pass
print(i)
# Out:
# 1

# %% [markdown]
# #80 puanı geçen kişinin numarası

# %%
list2=[]
i=0
for n in list:
  variable=n.replace(",",".")
  list2.append(variable)
for m in list2:
  if float(m[10:])>=80:
    number=m[0:10]
print(number)
# Out:
# 220542011
